# %% [markdown]
# Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [52 57 52 30 30 10 10 12 22 20 33 55 19 59 29 55 45 45 37 10 19 19 14 19
#  35 30 50 28 31 41 15 16 25 41 13 55 48 41 59 47 53 22 25 24 41 55 41 35
#  55 34]

# %%
no = [52,57,52,30,30,10,10,12,22,20,33,55,19,59,29,55,45,45,37,10,19,19,14,19,
 35,30,50,28,31,41,15,16,25,41,13,55,48,41,59,47,53,22,25,24,41,55,41,35,
 55,34]
l = [10,20,30,40,50,60]
plt.hist(no,color = "brown",bins=l,edgecolor="black")
plt.title("Graph")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no = [52,57,52,30,30,10,10,12,22,20,33,55,19,59,29,55,45,45,37,10,19,19,14,19,
 35,30,50,28,31,41,15,16,25,41,13,55,48,41,59,47,53,22,25,24,41,55,41,35,
 55,34]
l = [10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),edgecolor="black")
plt.title("Program")
plt.xlabel("java")
plt.ylabel("No.")
plt.show()

# %%
no = [52,57,52,30,30,10,10,12,22,20,33,55,19,59,29,55,45,45,37,10,19,19,14,19,
 35,30,50,28,31,41,15,16,25,41,13,55,48,41,59,47,53,22,25,24,41,55,41,35,
 55,34]
l = [10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),edgecolor="black",cumulative=-1)
plt.title("Program")
plt.xlabel("PHP")
plt.ylabel("No.")
plt.show()

# %%
no = [52,57,52,30,30,10,10,12,22,20,33,55,19,59,29,55,45,45,37,10,19,19,14,19,
 35,30,50,28,31,41,15,16,25,41,13,55,48,41,59,47,53,22,25,24,41,55,41,35,
 55,34]
l = [10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),edgecolor="black",histtype="step")
plt.title("Program")
plt.xlabel("c++")
plt.ylabel("No.")
plt.show()

# %%
no = [52,57,52,30,30,10,10,12,22,20,33,55,19,59,29,55,45,45,37,10,19,19,14,19,
 35,30,50,28,31,41,15,16,25,41,13,55,48,41,59,47,53,22,25,24,41,55,41,35,
 55,34]
l = [10,20,30,40,50,60]
plt.hist(no,bins=l,edgecolor="black",label="python")
plt.title("Program")
plt.xlabel("python")
plt.ylabel("No.")
plt.legend()
plt.show()

# %%
no = [52,57,52,30,30,10,10,12,22,20,33,55,19,59,29,55,45,45,37,10,19,19,14,19,
 35,30,50,28,31,41,15,16,25,41,13,55,48,41,59,47,53,22,25,24,41,55,41,35,
 55,34]
l = [10,20,30,40,50,60]
plt.hist(no,bins=l,edgecolor="black",label="python")
plt.title("Program")
plt.xlabel("python")
plt.ylabel("No.")
plt.axvline(45,color="r")
plt.legend()
plt.show()

# %%
no = [52,57,52,30,30,10,10,12,22,20,33,55,19,59,29,55,45,45,37,10,19,19,14,19,
 35,30,50,28,31,41,15,16,25,41,13,55,48,41,59,47,53,22,25,24,41,55,41,35,
 55,34]
l = [10,20,30,40,50,60]
plt.hist(no,bins=l,edgecolor="black",label="python")
plt.title("Program")
plt.xlabel("python")
plt.ylabel("No.")
plt.axvline(45,color="r")
plt.legend()
plt.grid()
plt.show()
